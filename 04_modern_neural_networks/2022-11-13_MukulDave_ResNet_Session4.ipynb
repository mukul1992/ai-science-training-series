# %% [markdown]
# ## Homework
#
# I modified the python script to write the loss and accuracy to a separate file at each iteration. Reading the values here and plotting.

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
loss = np.fromfile("myloss.txt",sep="\n")
loss.shape
acc = np.fromfile("myacc.txt",sep="\n")
acc.shape
# Out:
# (5004,)

# %%
plt.semilogy(loss)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.show()

# %%
plt.plot(acc)
plt.xlabel("iterations")
plt.ylabel("accuracy")
plt.show()
